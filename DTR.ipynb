# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor, plot_tree
import matplotlib.pyplot as plt

# Create a sample dataset
data = {
    'Experience (Years)': [1, 2, 3, 4, 5],
    'Salary (in $)': [30000, 35000, 40000, 45000, 50000]
}

# Convert the dictionary to a pandas DataFrame
df = pd.DataFrame(data)

# Split the data into features (X) and target (y)
X = df[['Experience (Years)']]
y = df['Salary (in $)']

# Create and train the Decision Tree model
dt_model = DecisionTreeRegressor(random_state=42)
dt_model.fit(X, y)

# Visualize the Decision Tree
plt.figure(figsize=(8, 6))
plot_tree(dt_model, feature_names=['Experience (Years)'], filled=True, rounded=True)
plt.title('Decision Tree Regressor')
plt.show()

# Get user input for prediction
user_experience = float(input("Enter years of experience to predict salary: "))
y_pred = dt_model.predict([[user_experience]])

# Show the predicted salary
print(f"The predicted salary for {user_experience} years of experience is: ${predicted_salary[0]:,.2f}")
# Out:
# The predicted salary for 2.5 years of experience is: $35,000.00
# c:\Users\ADMIN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
# Plot the actual data and the model's predictions
plt.figure(figsize=(8, 6))
plt.scatter(X, y, color='blue', label='Actual Data', zorder=5)  # Scatter plot for actual data
plt.plot(X, y_pred, color='red', label='Model Prediction', linewidth=2)  # Line graph for predictions

# Highlight the user input prediction
plt.scatter(user_experience, y_pred, color='green', label='User Prediction', s=100, zorder=10)

# Add labels and legend
plt.title('Decision Tree Regression')
plt.xlabel('Experience (Years)')
plt.ylabel('Salary (in $)')
plt.legend()
plt.grid(True)
plt.show()
